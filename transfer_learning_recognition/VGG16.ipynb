# %%
import models as md
import utils as ut

# Carregar a model
md.Models.VGG16.description
# Out:
# Using TensorFlow backend.
# 'Depth 23'

# %%
#Load the model
md.Models.VGG16.build()
# Out:
# Model Build ...
# ...

# %%
features, labels = md.Models.VGG16.get_features(ut.Directory.train)
ut.save_to_file("%s_vgg" % ut.Directory.train.name, features, labels)
# Out:
# Starting Doors images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# 380 images processed
# 390 images processed
# 400 images processed
# 410 images processed
# 420 images processed
# ...

# %%
features, labels = md.Models.VGG16.get_features(ut.Directory.validation)
ut.save_to_file("%s_vgg" % ut.Directory.validation.name, features, labels)
# Out:
# Starting Doors images
# cannot reshape array of size 200704 into shape (1,224,224,3)
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# cannot reshape array of size 200704 into shape (1,224,224,3)
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# ...

# %%
features, labels = md.Models.VGG16.get_features(ut.Directory.test)
ut.save_to_file("%s_vgg" % ut.Directory.test.name, features, labels)
# Out:
# Starting Doors images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# cannot reshape array of size 200704 into shape (1,224,224,3)
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# 380 images processed
# 390 images processed
# 400 images processed
# 410 images processed
# ...

# %%
import utils as ut
import models as md
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from keras_tqdm import TQDMCallback

train_x, train_labels = ut.read_file('%s_vgg' % ut.Directory.train.name)
train_y, _ = ut.get_data_labels(train_labels)

validation_x, validation_labels = ut.read_file('%s_vgg' % ut.Directory.validation.name)
validation_y, _ = ut.get_data_labels(validation_labels)

checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=10, verbose=1, mode='auto')
progress = TQDMCallback(leave_outer=False)

epochs = 100
batch_size=64

clf_model = Sequential()
clf_model.add(GlobalAveragePooling2D(input_shape=train_x.shape[1:]))
clf_model.add(Dense(2048, activation="relu"))
clf_model.add(Dense(1024, activation="relu"))
clf_model.add(Dense(512, activation="relu"))
clf_model.add(Dense(512, activation="relu"))
clf_model.add(Dense(5, activation="softmax"))
clf_model.compile(loss = "categorical_crossentropy", 
              optimizer = "adam", 
              metrics=["accuracy"])

clf_model.fit(train_x, train_y,
          batch_size=batch_size,
          epochs=epochs, verbose=0,
          validation_data=(validation_x, validation_y),
        callbacks = [checkpoint, early, progress])
# Out:
# ...
# Epoch: 0 - loss: 0.957, acc: 0.662:  94%|█████████▍| 3136/3319 [00:02<00:00, 1557.73it/s]
# Epoch: 0 - loss: 0.946, acc: 0.666, val_loss: 0.750, val_acc: 0.735: 100%|██████████| 3319/3319 [00:02<00:00, 794.05it/s]
# ...
# Epoch: 1:   0%|          | 0/3319 [00:00<?, ?it/s]
# Epoch 00001: val_acc improved from -inf to 0.73497, saving model to vgg16_1.h5
# ...
# Epoch: 1 - loss: 0.719, acc: 0.753:  98%|█████████▊| 3264/3319 [00:02<00:00, 1603.76it/s]
# Epoch: 1 - loss: 0.717, acc: 0.754, val_loss: 0.696, val_acc: 0.750: 100%|██████████| 3319/3319 [00:02<00:00, 357.37it/s]
# Training:   2%|▏         | 2/100 [00:05<04:37,  2.83s/it]
# Epoch 00002: val_acc improved from 0.73497 to 0.74969, saving model to vgg16_1.h5
# ...
# Epoch: 2 - loss: 0.680, acc: 0.760:  98%|█████████▊| 3264/3319 [00:02<00:00, 1555.83it/s]
# Epoch: 2 - loss: 0.678, acc: 0.761, val_loss: 0.658, val_acc: 0.763: 100%|██████████| 3319/3319 [00:02<00:00, 440.89it/s]
# ...

# %%
import utils as ut
import models as md
from keras.models import load_model

test_x, test_labels = ut.read_file('%s_vgg' % ut.Directory.test.name)
test_y, _ = ut.get_data_labels(test_labels)

model = load_model('vgg16_1.h5')
model.evaluate(test_x, test_y, batch_size=64)
# Out:
# 2441/2441 [==============================] - 1s 216us/step
# [0.63800071441751194, 0.78246620242491161]
