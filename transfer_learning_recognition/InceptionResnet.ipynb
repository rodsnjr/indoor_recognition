# %%
import models as md
import utils as ut

# Carregar a model
md.Models.INCEPTIONRESNET.description
# Out:
# Using TensorFlow backend.
# 'Depth 572, Top 1: 0.804 (Imagenet)'

# %%
#Load the model
md.Models.INCEPTIONRESNET.build()
# Out:
# Model Build ...
# ...

# %%
features, labels = md.Models.INCEPTIONRESNET.get_features(ut.Directory.train)
ut.save_to_file("%s_incresnet" % ut.Directory.train.name, features, labels)
# Out:
# Starting Doors images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# 380 images processed
# 390 images processed
# 400 images processed
# 410 images processed
# 420 images processed
# ...

# %%
features, labels = md.Models.INCEPTIONRESNET.get_features(ut.Directory.validation)
ut.save_to_file("%s_incresnet" % ut.Directory.validation.name, features, labels)
# Out:
# Starting Doors images
# cannot reshape array of size 200704 into shape (1,224,224,3)
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# cannot reshape array of size 200704 into shape (1,224,224,3)
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# ...

# %%
features, labels = md.Models.INCEPTIONRESNET.get_features(ut.Directory.test)
ut.save_to_file("%s_incresnet" % ut.Directory.test.name, features, labels)
# Out:
# Starting Doors images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# cannot reshape array of size 200704 into shape (1,224,224,3)
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# 380 images processed
# 390 images processed
# 400 images processed
# 410 images processed
# ...

# %%
import utils as ut
import models as md
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras_tqdm import TQDMCallback

train_x, train_labels = ut.read_file('%s_incresnet' % ut.Directory.train.name)
train_y, _ = ut.get_data_labels(train_labels)

print(train_x.shape)

validation_x, validation_labels = ut.read_file('%s_incresnet' % ut.Directory.validation.name)
validation_y, _ = ut.get_data_labels(validation_labels)

checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=5, verbose=1, mode='auto')
progress = TQDMCallback(leave_outer=False)

epochs = 15
batch_size=32

clf_model = Sequential()
clf_model.add(GlobalAveragePooling2D(input_shape=train_x.shape[1:]))
clf_model.add(Dense(1024, activation="relu"))
clf_model.add(Dense(5, activation="softmax"))
clf_model.compile(loss = "categorical_crossentropy", 
              optimizer = "adam", 
              metrics=["accuracy"])

clf_model.fit(train_x, train_y,
          batch_size=batch_size,
          epochs=epochs, verbose=0,
          validation_data=(validation_x, validation_y),
        callbacks = [checkpoint, early, progress])
# Out:
# (3319, 5, 5, 1536)
# ...
# Epoch: 0 - loss: 0.836, acc: 0.731:  99%|█████████▉| 3296/3319 [00:03<00:00, 1470.65it/s]
# Epoch 00001: val_acc improved from -inf to 0.78528, saving model to vgg16_1.h5
# Epoch: 0 - loss: 0.834, acc: 0.731, val_loss: 0.633, val_acc: 0.785: 100%|██████████| 3319/3319 [00:04<00:00, 75.22it/s]
# ...
# Epoch: 1 - loss: 0.563, acc: 0.791:  97%|█████████▋| 3232/3319 [00:02<00:00, 1546.77it/s]
# Epoch: 1 - loss: 0.562, acc: 0.790, val_loss: 0.604, val_acc: 0.783: 100%|██████████| 3319/3319 [00:02<00:00, 576.17it/s]
# ...
# Epoch: 2 - loss: 0.490, acc: 0.818:   6%|▌         | 192/3319 [00:00<00:01, 1613.77it/s]
# Epoch 00002: val_acc did not improve
# ...
# Epoch: 2 - loss: 0.512, acc: 0.806:  99%|█████████▉| 3296/3319 [00:02<00:00, 1519.90it/s]
# Epoch: 2 - loss: 0.511, acc: 0.807, val_loss: 0.609, val_acc: 0.800: 100%|██████████| 3319/3319 [00:02<00:00, 126.38it/s]
# ...
# Epoch: 3 - loss: 0.358, acc: 0.891:   4%|▍         | 128/3319 [00:00<00:02, 1220.03it/s]
# ...

# %%
import utils as ut
import models as md
from keras.models import load_model

test_x, test_labels = ut.read_file('%s_incresnet' % ut.Directory.test.name)
test_y, _ = ut.get_data_labels(test_labels)


model = load_model('vgg16_1.h5')
model.evaluate(test_x, test_y, batch_size=64)
# Out:
# 2441/2441 [==============================] - 1s 382us/step
# [0.58572485311043065, 0.80499795168357424]
