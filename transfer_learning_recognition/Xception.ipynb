# %%
import models as md
import utils as ut

# Carregar a model
md.Models.XCEPTION.description
# Out:
# Using TensorFlow backend.
# 'Depth 126'

# %%
#Load the model
md.Models.XCEPTION.build()
# Out:
# Model Build ...
# ...

# %%
features, labels = md.Models.XCEPTION.get_features(ut.Directory.train)
ut.save_to_file("%s_xcpt" % ut.Directory.train.name, features, labels)
# Out:
# Starting Doors images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# 380 images processed
# 390 images processed
# 400 images processed
# 410 images processed
# 420 images processed
# ...

# %%
features, labels = md.Models.XCEPTION.get_features(ut.Directory.validation)
ut.save_to_file("%s_xcpt" % ut.Directory.validation.name, features, labels)
# Out:
# Starting Doors images
# cannot reshape array of size 200704 into shape (1,224,224,3)
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# cannot reshape array of size 200704 into shape (1,224,224,3)
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# ...

# %%
features, labels = md.Models.XCEPTION.get_features(ut.Directory.test)
ut.save_to_file("%s_xcpt" % ut.Directory.test.name, features, labels)
# Out:
# Starting Doors images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# cannot reshape array of size 200704 into shape (1,224,224,3)
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# 380 images processed
# 390 images processed
# 400 images processed
# 410 images processed
# ...

# %%
import utils as ut
import models as md
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras_tqdm import TQDMCallback

train_x, train_labels = ut.read_file('%s_xcpt' % ut.Directory.train.name)
train_y, _ = ut.get_data_labels(train_labels)

print(train_x.shape)

validation_x, validation_labels = ut.read_file('%s_xcpt' % ut.Directory.validation.name)
validation_y, _ = ut.get_data_labels(validation_labels)

checkpoint = ModelCheckpoint("vgg16_1.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=5, verbose=1, mode='auto')
progress = TQDMCallback(leave_outer=False)

epochs = 15
batch_size=32

clf_model = Sequential()
clf_model.add(GlobalAveragePooling2D(input_shape=train_x.shape[1:]))
clf_model.add(Dense(1024, activation="relu"))
clf_model.add(Dense(5, activation="softmax"))
clf_model.compile(loss = "categorical_crossentropy", 
              optimizer = "adam", 
              metrics=["accuracy"])

clf_model.fit(train_x, train_y,
          batch_size=batch_size,
          epochs=epochs, verbose=0,
          validation_data=(validation_x, validation_y),
        callbacks = [checkpoint, early, progress])
# Out:
# (3319, 7, 7, 2048)
# ...
# Epoch: 0 - loss: 0.714, acc: 0.742:  96%|█████████▋| 3200/3319 [00:03<00:00, 890.58it/s]
# Epoch: 0 - loss: 0.708, acc: 0.743, val_loss: 0.565, val_acc: 0.791: 100%|██████████| 3319/3319 [00:04<00:00, 361.42it/s]
# ...
# Epoch: 1:   0%|          | 0/3319 [00:00<?, ?it/s]
# Epoch 00001: val_acc improved from -inf to 0.79141, saving model to vgg16_1.h5
# ...
# Epoch: 1 - loss: 0.503, acc: 0.815:  99%|█████████▉| 3296/3319 [00:03<00:00, 902.81it/s]
# Epoch: 1 - loss: 0.503, acc: 0.815, val_loss: 0.567, val_acc: 0.781: 100%|██████████| 3319/3319 [00:04<00:00, 112.86it/s]
# ...
# Epoch: 2 - loss: 0.391, acc: 0.875:   4%|▍         | 128/3319 [00:00<00:02, 1099.96it/s]
# Epoch 00002: val_acc did not improve
# ...
# Epoch: 2 - loss: 0.423, acc: 0.847:  98%|█████████▊| 3264/3319 [00:03<00:00, 1086.23it/s]
# Epoch: 2 - loss: 0.424, acc: 0.846, val_loss: 0.586, val_acc: 0.769: 100%|██████████| 3319/3319 [00:03<00:00, 237.04it/s]
# ...

# %%
import utils as ut
import models as md
from keras.models import load_model

test_x, test_labels = ut.read_file('%s_xcpt' % ut.Directory.test.name)
test_y, _ = ut.get_data_labels(test_labels)


model = load_model('vgg16_1.h5')
model.evaluate(test_x, test_y, batch_size=64)
# Out:
# 2441/2441 [==============================] - 1s 510us/step
# [0.57800478463483507, 0.80663662435870731]
